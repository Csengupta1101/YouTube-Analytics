# %%
#import modules
import os
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#let's create a variable to store our secret API Key
os.environ['Project API'] = "AIzaSyCEuFv94NJOhG0UbRAg285pEXZwza5BQF8"
yt_api = os.getenv('Project API')

# %%
yt_api
# Out:
# 'AIzaSyCEuFv94NJOhG0UbRAg285pEXZwza5BQF8'

# %%
# Now we will start on getting the data for a channel , we will need to get the channel id that we want to analyze
# Let's take baidik chatterjee's channel in consideration -

baidik_channel_id = "UCMxk7pJAUCzKWVSMMh1Ehww"

# %% [markdown]
# Now we need to get service for accesing the data , the details of code we will getting from referneces in youtube data api section

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
YT_service = build('youtube','v3',developerKey=yt_api)

# %%
## Let's create the function to get channel statistics
def get_channel_stats(youtube,baidik_channel_id):
    request = youtube.channels().list(
        part = 'snippet,contentDetails,statistics',
        id = baidik_channel_id)
    response = request.execute()
    data = dict(Channel_name = response['item'][0]['snippet']['title'],
    Subscribers = response['item'][0]['snippet']['title'])
    return response

# %%
#call the function

get_channel_stats(YT_service,baidik_channel_id)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '96K36CXEm3pFbhf8ABMMcP2BNAk',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 't-96jVszUhqEbyfVaB590W59CsY',
#    'id': 'UCMxk7pJAUCzKWVSMMh1Ehww',
#    'snippet': {'title': 'Baidik Chatterjee',
#     'description': 'My name is Baidik Chatterjee. Kolkata is my hometown. This is basically a Bengali travel vlogging channel.\n\n\nEmail Id- baidik.chatterjee21@gmail.com ',
#     'customUrl': '@baidikchatterjee',
#     'publishedAt': '2020-03-03T09:57:08.794028Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu-Nrm-TFLNktsQsv4v03uheSxlECpN4aNCYHZq2vg=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu-Nrm-TFLNktsQsv4v03uheSxlECpN4aNCYHZq2vg=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
# ...
